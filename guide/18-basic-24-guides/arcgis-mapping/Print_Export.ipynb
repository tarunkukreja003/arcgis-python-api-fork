# %% [markdown]
# # Export and Print Map

# %% [markdown]
# ## Import Class

# %%
from arcgis.map import Map
from arcgis.gis import GIS

gis = GIS(profile="your_online_profile")

# %%
new_map = gis.map()
new_map
# Out:
# Map(extent={'xmin': -13458971.714867678, 'ymin': 3612376.446092113, 'xmax': -12305256.512286382, 'ymax': 43548…

# %% [markdown]
# ## Using Print
# The ``print`` method prints the ``Map`` object to a printable file such as a PDF, PNG32, JPG.

# %%
new_map.print("JPG", new_map.extent)
# Out:
# 'https://utility.arcgisonline.com/arcgis/rest/directories/arcgisoutput/Utilities/PrintingTools_GPServer/x_____x6YoLK_gFnbqAtauyryit5g..x_____x_ags_47610410-d004-11ee-865a-0e206d5cb93d.jpg'

# %% [markdown]
# ## Export to HTML
# The ``export_to_html`` method takes the current state of the rendered map and exports it to a  standalone HTML file that can be viewed in any web browser.

# %%
new_map.export_to_html(r"C:\workspace\Content\testing\testing.html", "ExportTesting")

# %% [markdown]
# ![image.png](attachment:954db2d8-652c-41f4-927c-d2f41b7d3a9c.png)
